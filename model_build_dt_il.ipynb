# %% [markdown]
# #mengmeng wu
# #data cleaning
# #decision tree and random forest model building
# #model evalution

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("final_merge_il.csv")

# %% [markdown]
# ### data cleaning

# %%
df.shape
# Out:
# (1319, 682)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'GEO_ID', 'NAME_x', 'S1903_C01_001E', 'S1903_C01_001M',
#        'S1903_C02_001E', 'S1903_C02_001M', 'S1903_C01_002E', 'S1903_C01_002M',
#        'S1903_C02_002E',
#        ...
#        'DP05_0080M', 'DP05_0080PE', 'DP05_0080PM', 'DP05_0081E', 'DP05_0081M',
#        'DP05_0081PE', 'DP05_0081PM', 'Unnamed: 326', 'in_county', 'target'],
#       dtype='object', length=682)

# %%
#select the variables we need
selected_columns = ['target',"S1501_C01_014E","S1903_C02_001E", "S1903_C02_002E", "S1903_C02_003E", "DP05_0032PE", "DP05_0033PE"]

# %%
#mapping colname using codebook
colname_dic = {"S1501_C01_014E": "highschool degree or higher rate", 
               "S1903_C02_001E": "household median income", 
               "S1903_C02_002E": "white household median income",
               "S1903_C02_003E": "black household median income",
               "DP05_0032PE": "white race rate",
               "DP05_0033PE": "black race rate",
               "target": "one or more homicides"
               }

# %%
df = df[selected_columns]

# %%
df.columns
# Out:
# Index(['target', 'S1501_C01_014E', 'S1903_C02_001E', 'S1903_C02_002E',
#        'S1903_C02_003E', 'DP05_0032PE', 'DP05_0033PE'],
#       dtype='object')

# %%
#check if there is missing values 
null_sum = df.isnull().sum()

null_sum
# Out:
# target            0
# S1501_C01_014E    0
# S1903_C02_001E    0
# S1903_C02_002E    0
# S1903_C02_003E    0
# DP05_0032PE       0
# DP05_0033PE       0
# dtype: int64

# %%
df["S1501_C01_014E"].value_counts()
# Out:
# S1501_C01_014E
# 100.0    12
# 90.1     12
# 94.2     11
# 90.7     10
# 95.4     10
#          ..
# 45.8      1
# 68.4      1
# 58.4      1
# 54.6      1
# 51.2      1
# Name: count, Length: 419, dtype: int64

# %%
#replace dash with missing value
df.replace('-', np.nan, inplace=True)

# %%
df.isna().sum()
# Out:
# target              0
# S1501_C01_014E      4
# S1903_C02_001E      4
# S1903_C02_002E    185
# S1903_C02_003E    450
# DP05_0032PE         4
# DP05_0033PE         4
# dtype: int64

# %%
x_variable = ["S1501_C01_014E","S1903_C02_001E", "S1903_C02_002E", "S1903_C02_003E", "DP05_0032PE", "DP05_0033PE"]

# %%
#remove the str expressions before changing data type
for x in x_variable:
    df[x] = df[x].replace({
        ',': '',
        r'\-$': '',
        r'\+$': ''
    }, regex=True)

# %%
df.isna().sum()
# Out:
# target              0
# S1501_C01_014E      4
# S1903_C02_001E      4
# S1903_C02_002E    185
# S1903_C02_003E    450
# DP05_0032PE         4
# DP05_0033PE         4
# dtype: int64

# %%
df["S1501_C01_014E"].value_counts()
# Out:
# S1501_C01_014E
# 100.0    12
# 90.1     12
# 94.2     11
# 90.7     10
# 95.4     10
#          ..
# 61.6      1
# 45.8      1
# 68.4      1
# 58.4      1
# 51.2      1
# Name: count, Length: 418, dtype: int64

# %%
#convert the data type to numerical value
df[selected_columns] = df[selected_columns].astype('float')
df2 = df.copy()

# %%
#replace missing value in x using mean
for col in x_variable:  
    df[col].fillna(value = df[col].mean(), inplace=True)
# Out:
# /var/folders/3y/pp5rq62s315dq6zz6hm6ywg40000gn/T/ipykernel_45768/1433626373.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(value = df[col].mean(), inplace=True)

# %%
#drop missing value in x 
df2 = df2.dropna(subset=x_variable)

# %%
#check target value distribution
print(df['target'].value_counts())
print(df2['target'].value_counts())
# Out:
# target
# 0.0    1185
# 1.0     134
# Name: count, dtype: int64
# target
# 0.0    621
# 1.0     68
# Name: count, dtype: int64

# %% [markdown]
# we can see there is a large data imbalance with case 0 almost 10 times of case 1. We will further tackle this issue in the model building part.

# %%
#rename the column name
df.rename(columns=colname_dic, inplace=True)
df2.rename(columns=colname_dic, inplace=True)
x_variables = [col for col in df.columns if col != 'one or more homicides']

# %%
#data transformation
#check data distribution
import seaborn as sns
sns.histplot(df['household median income'])
# Out:
# <Axes: xlabel='household median income', ylabel='Count'>

# %% [markdown]
# some of the variables do not strictly follow the normal distribution. therefore, we choose minmax scaler to do data standardization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
df[x_variables] = scaler.fit_transform(df[x_variables])

# %% [markdown]
# ### model training

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# packages for machine learning 
import sklearn
from sklearn import tree
from sklearn.model_selection import train_test_split
import graphviz 

# packages for plot and visualization
import matplotlib.pyplot as plt
from matplotlib import pylab
import graphviz 
pylab.rcParams["figure.figsize"] = (2.0, 2.0)
# %matplotlib inline

# %%
X = df[[col for col in df.columns if col != 'one or more homicides']]
y = df["one or more homicides"]

# %%
# split the data into training and testing set
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.2, random_state=929)

# %%
# Create a DecisionTreeClassifier object.  
# 1. explore the base model fisrt. set criterion = "entropy" and random_state =929, and keep all the other parameters with the default value.
dt_clf1 = DecisionTreeClassifier(random_state=929,criterion='entropy')

# %%
dt_clf1 = dt_clf1.fit(X_train1, y_train1)

# %%
from sklearn.model_selection import KFold, cross_validate

# %%
# 2. Evaluate the DecisionTreeClassifier performance using kfolder
# Perform KFold splitting

kf = KFold(n_splits=5, shuffle=True, random_state=929)
scores = cross_validate(dt_clf1, X_train1, y_train1, cv=kf,
                       scoring=['accuracy', 'precision', 'recall'])


print("Accuracy scores: ", scores['test_accuracy'])
print("Precision scores: ", scores['test_precision'])
print("Recall scores: ", scores['test_recall'])

print("Mean Accuracy: ", scores['test_accuracy'].mean())
print("Mean Precision: ", scores['test_precision'].mean())
print("Mean Recall: ", scores['test_recall'].mean())
# Out:
# Accuracy scores:  [0.81990521 0.83412322 0.8436019  0.85308057 0.79146919]
# Precision scores:  [0.19047619 0.16666667 0.20689655 0.22727273 0.04545455]
# Recall scores:  [0.16       0.07407407 0.375      0.26315789 0.04166667]
# Mean Accuracy:  0.8284360189573459
# Mean Precision:  0.16735333631885355
# Mean Recall:  0.18277972709551654

# %% [markdown]
# 3.1 through validation, the first model we explore should be improved on the precision and recall score for case 1. The low scores are likely due to the data imblance. So we are 1/20 from the x value data in the original data for training

# %%
X_zeros = X_train1[y_train1 == 0]
y_zeros = y_train1[y_train1 == 0]
X_ones = X_train1[y_train1 == 1]
y_ones = y_train1[y_train1 == 1]

X_zeros_sampled = X_zeros.sample(n=len(X_zeros) // 10, random_state=929)
y_zeros_sampled = y_zeros[X_zeros_sampled.index]

X_train2= pd.concat([X_zeros_sampled, X_ones])
y_train2 = pd.concat([y_zeros_sampled, y_ones])

# %%
X_train2.shape
# Out:
# (205, 6)

# %%
pd.DataFrame([np.round(dt_clf1.feature_importances_,2)], columns= x_variables)
# Out:
#    highschool degree or higher rate  household median income  \
# 0                              0.16                      0.2
#
#    white household median income  black household median income  \
# 0                           0.12                           0.15
#
#    white race rate  black race rate
# 0             0.15             0.22

# %%
corr_matrix = df[x_variables].corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %% [markdown]
# 3.2 based on the feature importance and multicollinearity， I further filtered out two features

# %%
x_variables = ['highschool degree or higher rate', 'white household median income',
              'white race rate', 'black race rate']

# %%
df_update = df[x_variables + ['one or more homicides']]

# %%
X_train2 = X_train2[x_variables]

# %%
#check model complexity
dt_clf1.get_n_leaves()
# Out:
# 131

# %%
dt_clf1.get_depth()
# Out:
# 22

# %%
dt_clf1.tree_.n_node_samples
# Out:
# array([1055,  788,    6,    4,    1,    3,    2,  782,  724,    1,  723,
#         722,    5,    2,    3,  717,   96,    4,    2,    1,    1,    2,
#          92,  621,  145,   35,  110,  102,   81,   31,    5,    3,    2,
#           1,    2,   26,   50,    8,    4,    4,   42,    9,   33,    1,
#          32,    1,   31,   10,   21,   16,   11,    5,    3,    2,    1,
#           2,    5,    3,    2,   21,    8,    3,    5,    1,    4,  476,
#         276,  203,   84,    8,    7,    1,   76,  119,   11,    5,    6,
#           2,    4,    3,    1,  108,   63,   58,    5,    2,    1,    1,
#           3,   45,   11,   34,    2,   32,   20,   19,   17,   15,    2,
#           1,    1,    2,    1,    1,    1,   12,   73,  200,  158,   56,
#          45,   44,   31,   13,    5,    3,    2,    1,    2,    8,    1,
#          11,    3,    8,    1,    7,    6,    1,  102,   97,    5,    1,
#           4,   42,    6,    2,    4,    1,    3,   36,   21,   14,   12,
#           4,    2,    2,    8,    2,    7,   15,    1,   58,  267,    3,
#         264,   31,   20,    3,   17,    7,   10,    7,    4,    3,    1,
#           2,    3,   11,   10,    1,  233,   22,  211,   13,  198,  166,
#         153,   91,   13,    3,   10,    5,    3,    2,    5,   78,   60,
#           5,    2,    3,   55,   44,   42,    2,   40,   21,    4,   17,
#          15,    9,    6,    1,    5,    2,    1,    1,    3,    3,    6,
#           2,   19,    2,   11,   18,   15,    2,   13,    5,    2,    1,
#           1,    3,    8,    3,    5,    3,    2,    1,    2,    3,   62,
#          10,   52,   36,   31,   24,   21,   14,   11,    1,   10,    3,
#           7,    3,    7,    5,    4,    1,   16,    1,   15,   13,   32,
#          30,   28,    2,    1,    1,    2,    1,    1], dtype=int64)

# %%
#3.3 considering the model complexity, it may risk overfitting. so we then tune parameters using gridSearchCV
dt_clf2 = DecisionTreeClassifier(random_state=929,criterion='entropy', max_depth = 15, max_features = 4)

# %%
from sklearn.model_selection import GridSearchCV
dt_clf2 = DecisionTreeClassifier(random_state=929)

param_grid = {
    'max_depth': [5, 10, 15, 20,25,30],
    'max_features': [3,4],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
grid_cv = GridSearchCV(estimator=dt_clf2, param_grid=param_grid, cv=5,
                           scoring={
                            'precision': 'precision',
                            'recall': 'recall',
                            'accuracy': 'accuracy',
                            'f1-score': "f1"},
                            refit='recall') #choose recall here because the most important info for us to predict more cases which will happen in reality

grid_cv.fit(X_train2, y_train2)
# Print the accuracy of Decision Tree Classifier
print("Best parameters found: ", grid_cv.best_params_)
print("Best score achieved: ", grid_cv.best_score_)

print("\nDetailed cross-validation results:")
for params, mean_accuracy, mean_precision, mean_recall, mean_f1 in zip(
    grid_cv.cv_results_['params'],
    grid_cv.cv_results_['mean_test_accuracy'],
    grid_cv.cv_results_['mean_test_precision'],
    grid_cv.cv_results_['mean_test_recall'],
    grid_cv.cv_results_['mean_test_f1-score']
):
    print(f"\nParameters: {params}")
    print(f"Accuracy: {mean_accuracy:.3f}")
    print(f"Precision: {mean_precision:.3f}")
    print(f"Recall: {mean_recall:.3f}")
    print(f"f1-score: {mean_f1:.3f}")
# Out:
# Best parameters found:  {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best score achieved:  0.6490118577075099
#
# Detailed cross-validation results:
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.649
# f1-score: 0.625
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.600
# Precision: 0.643
# Recall: 0.622
# f1-score: 0.629
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.623
# Recall: 0.613
# f1-score: 0.617
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.585
# Precision: 0.623
# Recall: 0.649
# f1-score: 0.631
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.615
# Precision: 0.653
# Recall: 0.649
# f1-score: 0.647
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.595
# Precision: 0.630
# Recall: 0.630
# f1-score: 0.629
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.502
# Precision: 0.535
# Recall: 0.522
# f1-score: 0.527
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.502
# Precision: 0.535
# Recall: 0.522
# f1-score: 0.527
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.502
# Precision: 0.544
# Recall: 0.486
# f1-score: 0.512
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.561
# Precision: 0.606
# Recall: 0.567
# f1-score: 0.584
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.556
# Precision: 0.598
# Recall: 0.567
# f1-score: 0.581
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.613
# Recall: 0.585
# f1-score: 0.597
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.566
# Precision: 0.608
# Recall: 0.585
# f1-score: 0.595
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.601
# Recall: 0.585
# f1-score: 0.592
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.576
# Precision: 0.615
# Recall: 0.603
# f1-score: 0.607
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.527
# Precision: 0.571
# Recall: 0.550
# f1-score: 0.558
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.527
# Precision: 0.571
# Recall: 0.550
# f1-score: 0.558
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.537
# Precision: 0.582
# Recall: 0.559
# f1-score: 0.567
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.527
# Precision: 0.567
# Recall: 0.595
# f1-score: 0.575
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.577
# Recall: 0.595
# f1-score: 0.583
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.576
# Precision: 0.602
# Recall: 0.621
# f1-score: 0.610
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.584
# Recall: 0.568
# f1-score: 0.573
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.566
# Precision: 0.606
# Recall: 0.595
# f1-score: 0.595
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.537
# Precision: 0.572
# Recall: 0.631
# f1-score: 0.595
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.541
# Precision: 0.574
# Recall: 0.586
# f1-score: 0.577
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.599
# Recall: 0.612
# f1-score: 0.604
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.556
# Precision: 0.597
# Recall: 0.559
# f1-score: 0.576
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.604
# Recall: 0.586
# f1-score: 0.589
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.537
# Precision: 0.572
# Recall: 0.631
# f1-score: 0.595
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.541
# Precision: 0.574
# Recall: 0.586
# f1-score: 0.577
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.599
# Recall: 0.612
# f1-score: 0.604
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.556
# Precision: 0.597
# Recall: 0.559
# f1-score: 0.576
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.604
# Recall: 0.586
# f1-score: 0.589
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.537
# Precision: 0.572
# Recall: 0.631
# f1-score: 0.595
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.541
# Precision: 0.574
# Recall: 0.586
# f1-score: 0.577
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.599
# Recall: 0.612
# f1-score: 0.604
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.556
# Precision: 0.597
# Recall: 0.559
# f1-score: 0.576
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.604
# Recall: 0.586
# f1-score: 0.589
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.537
# Precision: 0.572
# Recall: 0.631
# f1-score: 0.595
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.541
# Precision: 0.574
# Recall: 0.586
# f1-score: 0.577
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.599
# Recall: 0.612
# f1-score: 0.604
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.556
# Precision: 0.597
# Recall: 0.559
# f1-score: 0.576
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.604
# Recall: 0.586
# f1-score: 0.589
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584

# %%
feature_importances = grid_cv.best_estimator_.feature_importances_

importance_df = pd.DataFrame(
    [np.round(feature_importances, 2)], 
    columns=x_variables
)

print(importance_df)
# Out:
#    highschool degree or higher rate  white household median income  \
# 0                              0.24                           0.13
#
#    white race rate  black race rate
# 0             0.47             0.16

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
dt_clf3 = RandomForestClassifier(n_estimators = 1000, criterion = 'entropy', random_state = 929,class_weight='balanced',max_depth = 20)

# %%
rf_clf = RandomForestClassifier(random_state=929)
rf_param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, 15, 20],
    'max_features': [3, 4],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

rf_grid = GridSearchCV(
    estimator=rf_clf, 
    param_grid=rf_param_grid, 
    cv=5,
    scoring = {
    'precision': 'precision',
    'recall': 'recall',
    'accuracy': 'accuracy',
    'f1-score': "f1"
},
    refit='recall')

rf_grid.fit(X_train2, y_train2)

print("Best parameters found: ", rf_grid.best_params_)
print("Best score achieved: ", rf_grid.best_score_)

print("\nDetailed cross-validation results:")
for params, mean_accuracy, mean_precision, mean_recall, mean_f1 in zip(
    grid_cv.cv_results_['params'],
    grid_cv.cv_results_['mean_test_accuracy'],
    grid_cv.cv_results_['mean_test_precision'],
    grid_cv.cv_results_['mean_test_recall'],
    grid_cv.cv_results_['mean_test_f1-score']
):
    print(f"\nParameters: {params}")
    print(f"Accuracy: {mean_accuracy:.3f}")
    print(f"Precision: {mean_precision:.3f}")
    print(f"Recall: {mean_recall:.3f}")
    print(f"f1-score: {mean_f1:.3f}")
# Out:
# Best parameters found:  {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Best score achieved:  0.6490118577075099
#
# Detailed cross-validation results:
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.649
# f1-score: 0.625
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.600
# Precision: 0.643
# Recall: 0.622
# f1-score: 0.629
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.623
# Recall: 0.613
# f1-score: 0.617
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.585
# Precision: 0.623
# Recall: 0.649
# f1-score: 0.631
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.615
# Precision: 0.653
# Recall: 0.649
# f1-score: 0.647
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.595
# Precision: 0.630
# Recall: 0.630
# f1-score: 0.629
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.502
# Precision: 0.535
# Recall: 0.522
# f1-score: 0.527
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.502
# Precision: 0.535
# Recall: 0.522
# f1-score: 0.527
#
# Parameters: {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.502
# Precision: 0.544
# Recall: 0.486
# f1-score: 0.512
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.561
# Precision: 0.606
# Recall: 0.567
# f1-score: 0.584
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.556
# Precision: 0.598
# Recall: 0.567
# f1-score: 0.581
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.613
# Recall: 0.585
# f1-score: 0.597
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.566
# Precision: 0.608
# Recall: 0.585
# f1-score: 0.595
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.601
# Recall: 0.585
# f1-score: 0.592
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.576
# Precision: 0.615
# Recall: 0.603
# f1-score: 0.607
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.527
# Precision: 0.571
# Recall: 0.550
# f1-score: 0.558
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.527
# Precision: 0.571
# Recall: 0.550
# f1-score: 0.558
#
# Parameters: {'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.537
# Precision: 0.582
# Recall: 0.559
# f1-score: 0.567
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.527
# Precision: 0.567
# Recall: 0.595
# f1-score: 0.575
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.577
# Recall: 0.595
# f1-score: 0.583
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.576
# Precision: 0.602
# Recall: 0.621
# f1-score: 0.610
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.584
# Recall: 0.568
# f1-score: 0.573
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.566
# Precision: 0.606
# Recall: 0.595
# f1-score: 0.595
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 10, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 10, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.537
# Precision: 0.572
# Recall: 0.631
# f1-score: 0.595
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.541
# Precision: 0.574
# Recall: 0.586
# f1-score: 0.577
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.599
# Recall: 0.612
# f1-score: 0.604
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.556
# Precision: 0.597
# Recall: 0.559
# f1-score: 0.576
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.604
# Recall: 0.586
# f1-score: 0.589
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 15, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.537
# Precision: 0.572
# Recall: 0.631
# f1-score: 0.595
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.541
# Precision: 0.574
# Recall: 0.586
# f1-score: 0.577
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.599
# Recall: 0.612
# f1-score: 0.604
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.556
# Precision: 0.597
# Recall: 0.559
# f1-score: 0.576
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.604
# Recall: 0.586
# f1-score: 0.589
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 20, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 20, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.537
# Precision: 0.572
# Recall: 0.631
# f1-score: 0.595
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.541
# Precision: 0.574
# Recall: 0.586
# f1-score: 0.577
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.599
# Recall: 0.612
# f1-score: 0.604
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.556
# Precision: 0.597
# Recall: 0.559
# f1-score: 0.576
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.604
# Recall: 0.586
# f1-score: 0.589
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 25, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 25, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.537
# Precision: 0.572
# Recall: 0.631
# f1-score: 0.595
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.541
# Precision: 0.574
# Recall: 0.586
# f1-score: 0.577
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.571
# Precision: 0.599
# Recall: 0.612
# f1-score: 0.604
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.556
# Precision: 0.597
# Recall: 0.559
# f1-score: 0.576
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.604
# Recall: 0.586
# f1-score: 0.589
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.605
# Precision: 0.638
# Recall: 0.630
# f1-score: 0.632
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.546
# Precision: 0.602
# Recall: 0.523
# f1-score: 0.554
#
# Parameters: {'max_depth': 30, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.546
# Precision: 0.580
# Recall: 0.577
# f1-score: 0.574
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.541
# Precision: 0.583
# Recall: 0.577
# f1-score: 0.577
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Accuracy: 0.580
# Precision: 0.631
# Recall: 0.577
# f1-score: 0.599
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Accuracy: 0.590
# Precision: 0.625
# Recall: 0.621
# f1-score: 0.621
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Accuracy: 0.576
# Precision: 0.616
# Recall: 0.587
# f1-score: 0.597
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Accuracy: 0.561
# Precision: 0.608
# Recall: 0.559
# f1-score: 0.579
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.585
# Precision: 0.632
# Recall: 0.594
# f1-score: 0.609
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}
# Accuracy: 0.551
# Precision: 0.596
# Recall: 0.550
# f1-score: 0.569
#
# Parameters: {'max_depth': 30, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Accuracy: 0.551
# Precision: 0.585
# Recall: 0.586
# f1-score: 0.584

# %% [markdown]
# ### model evaluation

# %%
import numpy as np
from collections import Counter
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y_pred = dt_clf1.predict(X_test1)
y_true = y_test1
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.89      0.90       241
#          1.0       0.10      0.13      0.12        23
#
#     accuracy                           0.83       264
#    macro avg       0.51      0.51      0.51       264
# weighted avg       0.84      0.83      0.83       264

# %% [markdown]
# model1: we can see although it has a high accuracy, the precision and recall for case 1 is very low. this indicates it can accurately predict for case 0 but due to data imbalance, has low predicting ability for case y.

# %%
X_test2 = X_test1[x_variables]

# %%
y_pred = grid_cv.predict(X_test2)
y_true = y_test1

# %%
y_prob = grid_cv.predict_proba(X_test2)
y_prob
# Out:
# array([[0.15789474, 0.84210526],
#        [0.45833333, 0.54166667],
#        [0.        , 1.        ],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.45833333, 0.54166667],
#        [0.0625    , 0.9375    ],
#        [1.        , 0.        ],
#        [0.15789474, 0.84210526],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.0625    , 0.9375    ],
#        [0.32258065, 0.67741935],
#        [1.        , 0.        ],
#        [0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [0.80952381, 0.19047619],
#        [0.45833333, 0.54166667],
#        [1.        , 0.        ],
#        [0.0625    , 0.9375    ],
#        [0.33333333, 0.66666667],
#        [1.        , 0.        ],
#        [0.33333333, 0.66666667],
#        [0.32258065, 0.67741935],
#        [0.15789474, 0.84210526],
#        [1.        , 0.        ],
#        [0.80952381, 0.19047619],
#        [0.3       , 0.7       ],
#        [0.45833333, 0.54166667],
#        [0.15789474, 0.84210526],
#        [0.32258065, 0.67741935],
#        [0.45833333, 0.54166667],
#        [0.32258065, 0.67741935],
#        [0.15789474, 0.84210526],
#        [0.        , 1.        ],
#        [0.32258065, 0.67741935],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.0625    , 0.9375    ],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.80952381, 0.19047619],
#        [0.32258065, 0.67741935],
#        [1.        , 0.        ],
#        [0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [0.45833333, 0.54166667],
#        [0.        , 1.        ],
#        [0.80952381, 0.19047619],
#        [0.32258065, 0.67741935],
#        [0.85714286, 0.14285714],
#        [0.6       , 0.4       ],
#        [0.45833333, 0.54166667],
#        [1.        , 0.        ],
#        [0.15789474, 0.84210526],
#        [0.45833333, 0.54166667],
#        [0.2       , 0.8       ],
#        [0.3       , 0.7       ],
#        [0.6       , 0.4       ],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.3       , 0.7       ],
#        [0.6       , 0.4       ],
#        [0.        , 1.        ],
#        [0.        , 1.        ],
#        [1.        , 0.        ],
#        [0.6       , 0.4       ],
#        [0.        , 1.        ],
#        [0.45833333, 0.54166667],
#        [0.15789474, 0.84210526],
#        [0.15789474, 0.84210526],
#        [0.15789474, 0.84210526],
#        [0.        , 1.        ],
#        [1.        , 0.        ],
#        [0.80952381, 0.19047619],
#        [0.3       , 0.7       ],
#        [0.80952381, 0.19047619],
#        [1.        , 0.        ],
#        [0.3       , 0.7       ],
#        [0.3       , 0.7       ],
#        [0.0625    , 0.9375    ],
#        [0.32258065, 0.67741935],
#        [0.0625    , 0.9375    ],
#        [1.        , 0.        ],
#        [0.6       , 0.4       ],
#        [0.2       , 0.8       ],
#        [0.32258065, 0.67741935],
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [0.80952381, 0.19047619],
#        [0.        , 1.        ],
#        [0.32258065, 0.67741935],
#        [0.85714286, 0.14285714],
#        [0.        , 1.        ],
#        [0.45833333, 0.54166667],
#        [0.15789474, 0.84210526],
#        [0.6       , 0.4       ],
#        [0.45833333, 0.54166667],
#        [0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [0.        , 1.        ],
#        [0.        , 1.        ],
#        [0.85714286, 0.14285714],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.45833333, 0.54166667],
#        [0.85714286, 0.14285714],
#        [0.15789474, 0.84210526],
#        [0.32258065, 0.67741935],
#        [0.15789474, 0.84210526],
#        [1.        , 0.        ],
#        [0.6       , 0.4       ],
#        [0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [0.45833333, 0.54166667],
#        [0.45833333, 0.54166667],
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [0.33333333, 0.66666667],
#        [1.        , 0.        ],
#        [0.        , 1.        ],
#        [0.45833333, 0.54166667],
#        [0.85714286, 0.14285714],
#        [0.45833333, 0.54166667],
#        [0.6       , 0.4       ],
#        [0.15789474, 0.84210526],
#        [1.        , 0.        ],
#        [0.80952381, 0.19047619],
#        [0.80952381, 0.19047619],
#        [0.15789474, 0.84210526],
#        [0.15789474, 0.84210526],
#        [0.45833333, 0.54166667],
#        [0.15789474, 0.84210526],
#        [0.15789474, 0.84210526],
#        [0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [0.15789474, 0.84210526],
#        [0.45833333, 0.54166667],
#        [0.        , 1.        ],
#        [0.85714286, 0.14285714],
#        [0.3       , 0.7       ],
#        [0.80952381, 0.19047619],
#        [0.85714286, 0.14285714],
#        [0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [0.85714286, 0.14285714],
#        [1.        , 0.        ],
#        [0.32258065, 0.67741935],
#        [0.85714286, 0.14285714],
#        [1.        , 0.        ],
#        [0.6       , 0.4       ],
#        [0.15789474, 0.84210526],
#        [0.32258065, 0.67741935],
#        [0.15789474, 0.84210526],
#        [0.85714286, 0.14285714],
#        [0.45833333, 0.54166667],
#        [0.6       , 0.4       ],
#        [0.45833333, 0.54166667],
#        [0.3       , 0.7       ],
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [0.80952381, 0.19047619],
#        [0.80952381, 0.19047619],
#        [0.15789474, 0.84210526],
#        [0.15789474, 0.84210526],
#        [0.45833333, 0.54166667],
#        [0.        , 1.        ],
#        [1.        , 0.        ],
#        [0.0625    , 0.9375    ],
#        [0.85714286, 0.14285714],
#        [0.32258065, 0.67741935],
#        [1.        , 0.        ],
#        [0.15789474, 0.84210526],
#        [0.32258065, 0.67741935],
#        [0.3       , 0.7       ],
#        [1.        , 0.        ],
#        [0.80952381, 0.19047619],
#        [0.6       , 0.4       ],
#        [0.45833333, 0.54166667],
#        [0.80952381, 0.19047619],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.80952381, 0.19047619],
#        [0.15789474, 0.84210526],
#        [0.85714286, 0.14285714],
#        [0.80952381, 0.19047619],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.45833333, 0.54166667],
#        [0.32258065, 0.67741935],
#        [0.85714286, 0.14285714],
#        [0.15789474, 0.84210526],
#        [0.        , 1.        ],
#        [0.45833333, 0.54166667],
#        [1.        , 0.        ],
#        [0.80952381, 0.19047619],
#        [0.15789474, 0.84210526],
#        [1.        , 0.        ],
#        [0.        , 1.        ],
#        [0.80952381, 0.19047619],
#        [0.45833333, 0.54166667],
#        [0.3       , 0.7       ],
#        [0.45833333, 0.54166667],
#        [0.32258065, 0.67741935],
#        [1.        , 0.        ],
#        [0.15789474, 0.84210526],
#        [0.45833333, 0.54166667],
#        [0.3       , 0.7       ],
#        [0.3       , 0.7       ],
#        [1.        , 0.        ],
#        [0.15789474, 0.84210526],
#        [1.        , 0.        ],
#        [0.33333333, 0.66666667],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.0625    , 0.9375    ],
#        [0.3       , 0.7       ],
#        [0.45833333, 0.54166667],
#        [0.3       , 0.7       ],
#        [0.        , 1.        ],
#        [1.        , 0.        ],
#        [0.        , 1.        ],
#        [0.        , 1.        ],
#        [0.45833333, 0.54166667],
#        [0.45833333, 0.54166667],
#        [0.32258065, 0.67741935],
#        [0.85714286, 0.14285714],
#        [1.        , 0.        ],
#        [0.32258065, 0.67741935],
#        [0.32258065, 0.67741935],
#        [0.15789474, 0.84210526],
#        [0.3       , 0.7       ],
#        [0.        , 1.        ],
#        [1.        , 0.        ],
#        [0.45833333, 0.54166667],
#        [0.32258065, 0.67741935],
#        [0.85714286, 0.14285714],
#        [0.45833333, 0.54166667],
#        [0.45833333, 0.54166667],
#        [0.45833333, 0.54166667],
#        [0.32258065, 0.67741935],
#        [0.        , 1.        ],
#        [0.80952381, 0.19047619],
#        [0.45833333, 0.54166667],
#        [0.45833333, 0.54166667],
#        [0.15789474, 0.84210526],
#        [0.32258065, 0.67741935],
#        [1.        , 0.        ],
#        [0.3       , 0.7       ],
#        [0.15789474, 0.84210526],
#        [0.32258065, 0.67741935],
#        [0.80952381, 0.19047619],
#        [0.32258065, 0.67741935],
#        [0.15789474, 0.84210526],
#        [1.        , 0.        ],
#        [0.        , 1.        ],
#        [0.45833333, 0.54166667],
#        [0.32258065, 0.67741935],
#        [0.3       , 0.7       ],
#        [1.        , 0.        ],
#        [0.3       , 0.7       ]])

# %%
from sklearn.metrics import roc_curve, auc
# Predict probabilities instead of labels
y_prob = grid_cv.predict_proba(X_test2)[:, 1]  # Get probabilities for class 1

# Compute ROC curve
fpr, tpr, _ = roc_curve(y_true, y_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# from the roc curve, we can see auc 0.58， which indicates we have a little above average ability to distinct values

# %%
confusion_matrix(y_true, y_pred,labels=[0,1])
# Out:
# array([[ 86, 155],
#        [  7,  16]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.36      0.51       241
#          1.0       0.09      0.70      0.16        23
#
#     accuracy                           0.39       264
#    macro avg       0.51      0.53      0.34       264
# weighted avg       0.85      0.39      0.48       264

# %%
y_pred = rf_grid.predict(X_test2)
y_true = y_test1
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.46      0.61       241
#          1.0       0.10      0.65      0.18        23
#
#     accuracy                           0.47       264
#    macro avg       0.52      0.55      0.40       264
# weighted avg       0.86      0.47      0.57       264

# %% [markdown]
# as expected, the performance of model 2 and model 3 both shows an obvious increase in recall. Model 3 demonstrates a more balanced performance across other measurement compared to Model 2. However, model2 and model3 both performs low in precision for case1. The reason is that to increase recall, the model may sacrifice precision, leaning towards predicting samples as class 1 (resulting in high recall for class 1 but low precision).

# %% [markdown]
# result analysis are included in the model_build_dt_ca
