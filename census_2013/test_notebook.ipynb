# %%
import pandas as pd

# %%
ny_final = pd.read_csv('ny_final.csv')
il_final = linear_regression.merger_state("illinois")
ca_final = linear_regression.merger_state("california")
# Out:
# /Users/river/Desktop/MACS-30100/macs-30100-police-proj/linear_regression/linear_regression.py:57: DtypeWarning: Columns (2,3,58,59,82,83,124,125,126,127,128,129,154,155,156,157,158,159,214,215,216,217,218,219,232,233,234,235,236,237,250,251,252,253,254,255,268,269,270,271,272,273) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(census_file_path)
# /Users/river/Desktop/MACS-30100/macs-30100-police-proj/linear_regression/linear_regression.py:57: DtypeWarning: Columns (2,3,58,59,82,83,124,125,126,127,128,129,154,155,156,157,158,159,214,215,216,217,218,219,232,233,234,235,236,237,250,251,252,253,254,255,268,269,270,271,272,273) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(census_file_path)
# ...

# %%
ny_final
# Out:
#                    GEO_ID                name   age  gender          race  \
# 0    1400000US36065021104           Nyah Mway  13.0    Male         Asian
# 1    1400000US36065021104      Shatelle Hooks  35.0    Male         Black
# 2    1400000US36081097204    Quayshawn Samuel  31.0    Male         Black
# 3    1400000US36055009605        Mark Gaskill  28.0    Male         White
# 4    1400000US36081099200       Zabina Gafoor  52.0  Female         Asian
# ..                    ...                 ...   ...     ...           ...
# 314  1400000US36119006700      Jarrell Garris  37.0    Male         Black
# 315  1400000US36067000700     Sahlah Ridgeway  32.0  Female         Black
# 316  1400000US36119010803  Jonathan Maldonado  21.0    Male      Hispanic
# 317  1400000US36067015500     Kenneth Bennett  61.0    Male  Unknown race
# 318  1400000US36027050104        John Terzani  40.0    Male         White
#
#            date                                street_address  \
# ...

# %%
ca_final
# Out:
#                     GEO_ID                       name   age  gender  \
# 0     1400000US06105000500        Shirley Jean Peeler  51.0  Female
# 1     1400000US06087100801              Jeremy Goulet  35.0    Male
# 2     1400000US06037231601     Patrick Othro Sullivan  74.0    Male
# 3     1400000US06047002203                  Sonny Lam  43.0    Male
# 4     1400000US06037481001              Khan Tony Nim  35.0    Male
# ...                    ...                        ...   ...     ...
# 1900  1400000US06065041408          Ryan Joseph Smith  26.0    Male
# 1901  1400000US06083002008     Jose Manuel Reyes Rios  19.0    Male
# 1902  1400000US06083002703      Connor Jeffrey Amador  20.0    Male
# 1903  1400000US06019004212  Maximiliano "Max" Sosa Jr  33.0    Male
# 1904  1400000US06059001301           Austin Heiselman  48.0    Male
#
#               race       date                               street_address  \
# ...

# %%
il_final
# Out:
#                    GEO_ID                     name   age  gender  \
# 0    1400000US17111870104             Tony Starnes  45.0    Male
# 1    1400000US17031803017         Eric M. Anderson  41.0    Male
# 2    1400000US17113005104        Stephen P. Bethea  53.0    Male
# 3    1400000US17031834500          Christian Green  17.0    Male
# 4    1400000US17031681000          Michael Westley  15.0    Male
# ..                    ...                      ...   ...     ...
# 290  1400000US17121952400              Todd Pearce  30.0    Male
# 291  1400000US17097861201            Brandon Barry  22.0    Male
# 292  1400000US17197881603              Jamal Smith  31.0    Male
# 293  1400000US17037001500  Graciela Reza-Contreras  59.0  Female
# 294  1400000US17175951400       Rodney G. Williams  66.0    Male
#
#              race       date                 street_address  \
# 0    Unknown race 2013-05-10        10910 North Main Street
# 1           White 2013-12-13              1900 N Windham Ct
# ...

# %%
cd census_2013/
# Out:
# [Errno 2] No such file or directory: 'census_2013/'
# /Users/river/Desktop/MACS-30100/macs-30100-police-proj/census_2013

# %%
ca_race = pd.read_csv('california_race.csv')
ca_prev = pd.read_csv('california_census_2013.csv')
ca_2013 = ca_prev.merge(ca_race, on="GEO_ID")
ca_2013.to_csv('ca_2013.csv', index=False)
# Out:
# /var/folders/6l/cmpq4f_96xv7_3p8k362lbnr0000gn/T/ipykernel_32911/1526371021.py:1: DtypeWarning: Columns (2,3,4,6,7,10,11,14,15,18,19,22,23,26,27,30,31,34,35,38,39,42,43,46,47,50,51,54,55,58,59,62,63,70,71,74,75,78,79,82,83,86,87,88,90,91,94,95,98,99,100,102,103,106,107,110,111,112,114,115,118,119,122,123,126,127,130,131,134,135,138,139,142,143,146,147,150,151,154,155,158,159,162,163,166,167,170,171,174,175,178,179,182,183,186,187,190,191,194,195,198,199,202,203,206,207,210,211,214,215,218,219,222,223,226,227,230,231,232,234,235,238,239,242,243,246,247,250,251,254,255,258,259,260,262,263,266,267,270,271,274,275,278,279,282,283,286,287,290,291,294,295,298,299,302,303,306,307,310,311,314,315,318,319,322,323) have mixed types. Specify dtype option on import or set low_memory=False.
#   ca_race = pd.read_csv('california_race.csv')
# ...

# %%
il_race = pd.read_csv('illinois_race.csv')
il_prev = pd.read_csv('illinois_census_2013.csv')
il_2013 = il_prev.merge(il_race, on="GEO_ID")
il_2013.to_csv('il_2013.csv', index=False)
# Out:
# /var/folders/6l/cmpq4f_96xv7_3p8k362lbnr0000gn/T/ipykernel_32911/2513833859.py:1: DtypeWarning: Columns (2,3,4,6,7,10,11,14,15,18,19,22,23,26,27,30,31,34,35,38,39,42,43,46,47,50,51,54,55,58,59,62,63,70,71,74,75,78,79,82,83,86,87,88,90,91,94,95,98,99,100,102,103,106,107,110,111,112,114,115,118,119,122,123,126,127,130,131,134,135,138,139,142,143,146,147,150,151,154,155,158,159,162,163,166,167,170,171,174,175,178,179,182,183,186,187,190,191,194,195,198,199,202,203,206,207,210,211,214,215,218,219,222,223,226,227,230,231,232,234,235,238,239,242,243,246,247,250,251,254,255,258,259,260,262,263,266,267,270,271,274,275,278,279,282,283,286,287,290,291,294,295,298,299,302,303,306,307,310,311,314,315,318,319,322,323) have mixed types. Specify dtype option on import or set low_memory=False.
#   il_race = pd.read_csv('illinois_race.csv')
# ...

# %%
ny_education
# Out:
#                     GEO_ID                                        NAME  \
# 0                Geography                        Geographic Area Name
# 1     1400000US36001000100     Census Tract 1, Albany County, New York
# 2     1400000US36001000200     Census Tract 2, Albany County, New York
# 3     1400000US36001000300     Census Tract 3, Albany County, New York
# 4     1400000US36001000401  Census Tract 4.01, Albany County, New York
# ...                    ...                                         ...
# 4914  1400000US36123150100   Census Tract 1501, Yates County, New York
# 4915  1400000US36123150200   Census Tract 1502, Yates County, New York
# 4916  1400000US36123150300   Census Tract 1503, Yates County, New York
# 4917  1400000US36123150400   Census Tract 1504, Yates County, New York
# 4918  1400000US36123150500   Census Tract 1505, Yates County, New York
#
#                                   S1501_C01_001E  \
# 0     Total!!Estimate!!Population 18 to 24 years
# ...

# %%
ny_race = pd.read_csv('new_york_race.csv')
ny_income = pd.read_csv('new_york_income.csv')
ny_education = pd.read_csv('new_york_education.csv')
ny_prev = ny_income.merge(ny_education, on="GEO_ID")
ny_2013 = ny_prev.merge(ny_race, on="GEO_ID")
ny_2013.to_csv('ny_2013.csv', index=False)
# Out:
# /var/folders/6l/cmpq4f_96xv7_3p8k362lbnr0000gn/T/ipykernel_32911/1466844372.py:1: DtypeWarning: Columns (2,3,4,6,7,10,11,14,15,18,19,22,23,26,27,30,31,34,35,38,39,42,43,46,47,50,51,54,55,58,59,62,63,70,71,74,75,78,79,82,83,86,87,88,90,91,94,95,98,99,100,102,103,106,107,110,111,112,114,115,118,119,122,123,126,127,130,131,134,135,138,139,142,143,146,147,150,151,154,155,158,159,162,163,166,167,170,171,174,175,178,179,182,183,186,187,190,191,194,195,198,199,202,203,206,207,210,211,214,215,218,219,222,223,226,227,230,231,232,234,235,238,239,242,243,246,247,250,251,254,255,258,259,260,262,263,266,267,270,271,274,275,278,279,282,283,286,287,290,291,294,295,298,299,302,303,306,307,310,311,314,315,318,319,322,323) have mixed types. Specify dtype option on import or set low_memory=False.
#   ny_race = pd.read_csv('new_york_race.csv')
# ...

# %%
cd '/Users/river/Desktop/MACS-30100/macs-30100-police-proj/'
# Out:
# /Users/river/Desktop/MACS-30100/macs-30100-police-proj

# %%
import acs_merge_police

# %%
cd '/Users/river/Desktop/MACS-30100/macs-30100-police-proj/census_2013'
# Out:
# /Users/river/Desktop/MACS-30100/macs-30100-police-proj/census_2013

# %%
ny_2013 = pd.read_csv('ny_2013.csv')
il_2013 = pd.read_csv('il_2013.csv')
ca_2013 = pd.read_csv('ca_2013.csv')
# Out:
# /var/folders/6l/cmpq4f_96xv7_3p8k362lbnr0000gn/T/ipykernel_36010/1793219.py:1: DtypeWarning: Columns (2,3,58,59,82,83,124,125,126,127,128,129,154,155,156,157,158,159,214,215,216,217,218,219,232,233,234,235,236,237,250,251,252,253,254,255,268,269,270,271,272,273,354,355,356,358,359,362,363,366,367,370,371,374,375,378,379,382,383,386,387,390,391,394,395,398,399,402,403,406,407,410,411,414,415,422,423,426,427,430,431,434,435,438,439,440,442,443,446,447,450,451,452,454,455,458,459,462,463,464,466,467,470,471,474,475,478,479,482,483,486,487,490,491,494,495,498,499,502,503,506,507,510,511,514,515,518,519,522,523,526,527,530,531,534,535,538,539,542,543,546,547,550,551,554,555,558,559,562,563,566,567,570,571,574,575,578,579,582,583,584,586,587,590,591,594,595,598,599,602,603,606,607,610,611,612,614,615,618,619,622,623,626,627,630,631,634,635,638,639,642,643,646,647,650,651,654,655,658,659,662,663,666,667,670,671,674,675) have mixed types. Specify dtype option on import or set low_memory=Fals
# ...

# %%
cd ..
# Out:
# /Users/river/Desktop/MACS-30100/macs-30100-police-proj

# %%
geo_df_ny = acs_merge_police.tract_merger('/Users/river/Desktop/MACS-30100/macs-30100-police-proj/police_data.csv', '/Users/river/Desktop/MACS-30100/macs-30100-police-proj/new_york_shapefiles')
df_ny = acs_merge_police.attr_merger(geo_df_ny, '/Users/river/Desktop/MACS-30100/macs-30100-police-proj/census_2013/ny_2013.csv', ['Bronx County', 'Kings County', 'New York County', 'Queens County', 'Richmond County'])

# %%
geo_df_ca = acs_merge_police.tract_merger('/Users/river/Desktop/MACS-30100/macs-30100-police-proj/police_data.csv', '/Users/river/Desktop/MACS-30100/macs-30100-police-proj/california_shapefiles')
df_ca = acs_merge_police.attr_merger(geo_df_ca, '/Users/river/Desktop/MACS-30100/macs-30100-police-proj/census_2013/ca_2013.csv', ['Bronx County', 'Kings County', 'New York County', 'Queens County', 'Richmond County'])
